# %% [markdown]
# # Lesson 02 — Linear Regression
#
# Work through each task in order. Read the instructions in `practical/task/README.md` before starting.
#
# **Name:** `<your name>`
# **Date:** `<date>`

# %%
# Standard imports — do not modify
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 5)

# %% [markdown]
# ---
# ## Task 1 — Load and Explore the Dataset

# %%
# TODO: Load the dataset
# df = pd.read_csv('../datasets/<filename>.csv')
# df.head()

# %%
# TODO: Scatter plots — feature vs target for each feature

# %%
# TODO: Correlation matrix

# %% [markdown]
# ---
# ## Task 2 — Ordinary Least Squares (OLS)
#
# Implement the closed-form solution: `w* = (XᵀX)⁻¹ Xᵀy`

# %%
def ols_fit(X, y):
    """Return weight vector w* using the OLS closed-form solution."""
    # TODO: implement OLS
    raise NotImplementedError


def ols_predict(X, w):
    """Return predictions given feature matrix X and weight vector w."""
    # TODO: implement prediction
    raise NotImplementedError

# %%
# TODO: Prepare X and y, add a bias column to X, split into train/test
# Then fit OLS and compare against sklearn LinearRegression

# %%
# TODO: Report MSE, RMSE, MAE, and R² on the test set

# %% [markdown]
# ---
# ## Task 3 — Gradient Descent

# %%
def gradient_descent(X, y, learning_rate=0.01, n_iterations=1000):
    """
    Fit linear regression via batch gradient descent.
    Returns: (w, loss_history)
    """
    # TODO: implement gradient descent
    raise NotImplementedError

# %%
# TODO: Train with different learning rates and plot loss curves
# learning_rates = [0.001, 0.01, 0.1]

# %% [markdown]
# ---
# ## Task 4 — Regularisation
#
# Compare Ridge, Lasso, and Elastic Net using cross-validation.

# %%
# TODO: Scale features (important for regularised models)
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled  = scaler.transform(X_test)

# %%
# TODO: Cross-validate Ridge for different alpha values
# alphas = [0.01, 0.1, 1, 10, 100]

# %%
# TODO: Repeat for Lasso and Elastic Net
# Compare the learned coefficient vectors — which ones does Lasso zero out?

# %% [markdown]
# ---
# ## Task 5 — Residual Analysis

# %%
# TODO: Plot residuals vs predicted values for the best model
# Look for patterns that indicate heteroscedasticity

# %%
# TODO: Q-Q plot of residuals (use scipy.stats.probplot)

# %% [markdown]
# ---
# ## Task 6 — Reflection
#
# Answer the questions below in this markdown cell.
#
# 1. **When would you prefer Lasso over Ridge regression? Give a concrete example.**
#    *Your answer here.*
#
# 2. **What happens to the OLS solution when XᵀX is singular?**
#    *Your answer here.*
#
# 3. **How does gradient descent behave when the learning rate is too large?**
#    *Your answer here.*
