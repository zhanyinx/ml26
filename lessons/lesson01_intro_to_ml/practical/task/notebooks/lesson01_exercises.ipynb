# %% [markdown]
# # Lesson 01 — Introduction to Machine Learning
#
# Work through each task in order. Read the instructions in `practical/task/README.md` before starting.
#
# **Name:** `<your name>`
# **Date:** `<date>`

# %%
# Standard imports — do not modify
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.neighbors import KNeighborsClassifier
from sklearn.dummy import DummyClassifier

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 5)

# %% [markdown]
# ---
# ## Task 1 — Exploratory Data Analysis (EDA)
#
# Load the dataset from the `datasets/` folder and perform an initial exploration.

# %%
# TODO: Load the dataset
# df = pd.read_csv('../datasets/<filename>.csv')
# print(df.shape)
# df.head()

# %%
# TODO: Inspect data types and missing values

# %%
# TODO: Summary statistics

# %%
# TODO: Plot histograms for each feature

# %%
# TODO: Correlation heatmap

# %% [markdown]
# ---
# ## Task 2 — Train / Validation / Test Split
#
# Split the data and verify the class distribution is preserved.

# %%
# TODO: Define X (features) and y (target)
# X = df.drop(columns=['target'])
# y = df['target']

# TODO: Split into train+val and test (70/30), then split train+val into train and val
# Hint: use train_test_split with stratify=y

# %%
# TODO: Verify class distribution in each split

# %% [markdown]
# ---
# ## Task 3 — Baseline Model
#
# Train a majority-class dummy classifier and evaluate it on the validation set.

# %%
# TODO: Train a DummyClassifier with strategy='most_frequent'
# Report accuracy on the validation set

# %% [markdown]
# ---
# ## Task 4 — K-Nearest Neighbours Classifier

# %%
# TODO: Train a KNN classifier with k=5 and evaluate on the validation set
# Show accuracy and confusion matrix

# %%
# TODO: Plot validation accuracy vs k for k in [1, 3, 5, 10, 20]

# %% [markdown]
# ---
# ## Task 5 — Reflection
#
# Answer the questions below in this markdown cell.
#
# 1. **What does a high training accuracy but low validation accuracy indicate?**
#    *Your answer here.*
#
# 2. **How would you decide between two models with similar validation accuracy but different training times?**
#    *Your answer here.*
#
# 3. **What additional steps would you take before deploying a model?**
#    *Your answer here.*
